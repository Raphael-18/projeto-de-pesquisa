# %%
import configparser

# %%
import os
os.chdir('D:/GitHub/projeto-de-pesquisa')

# %%
config = configparser.ConfigParser()

# %%
config.read('config.ini')
# Out:
# ['config.ini']

# %%
config['ObjectiveFunction']['FO']
# Out:
# '1'

# %%
config['Simulation']['simulation_flag']
# Out:
# '1'

# %%
config['Simulation']['simulation_days']
# Out:
# '677'
